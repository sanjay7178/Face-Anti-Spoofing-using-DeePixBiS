# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay7178/Face-Anti-Spoofing-using-DeePixBiS/blob/main/EfficientDet_train_on_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zylo117/Yet-Another-EfficientDet-Pytorch.git
# Out:
# Cloning into 'Yet-Another-EfficientDet-Pytorch'...
# remote: Enumerating objects: 765, done.
# remote: Total 765 (delta 0), reused 0 (delta 0), pack-reused 765
# Receiving objects: 100% (765/765), 8.84 MiB | 18.26 MiB/s, done.
# Resolving deltas: 100% (437/437), done.

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1_C5iLHojj_MaG0Ql9PxXaSq7e5y2uG66' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1_C5iLHojj_MaG0Ql9PxXaSq7e5y2uG66" -O coco.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-04-07 17:00:51--  https://docs.google.com/uc?export=download&confirm=t&id=1_C5iLHojj_MaG0Ql9PxXaSq7e5y2uG66
# Resolving docs.google.com (docs.google.com)... 172.217.194.102, 172.217.194.113, 172.217.194.138, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-b8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3g2u1jg4ipe5rupcrpfodfq3t5b3ak87/1680886800000/02257514593413773851/*/1_C5iLHojj_MaG0Ql9PxXaSq7e5y2uG66?e=download&uuid=163dc82e-b1ef-48ac-b009-73543698e007 [following]
# ...
# --2023-04-07 17:00:52--  https://doc-14-b8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3g2u1jg4ipe5rupcrpfodfq3t5b3ak87/1680886800000/02257514593413773851/*/1_C5iLHojj_MaG0Ql9PxXaSq7e5y2uG66?e=download&uuid=163dc82e-b1ef-48ac-b009-73543698e007
# ...

# %%
# !unzip coco.zip > /dev/null

# %%
# %cd Yet-Another-EfficientDet-Pytorch
# Out:
# /content/Yet-Another-EfficientDet-Pytorch

# %%
# !wget https://github.com/zylo117/Yet-Another-Efficient-Pytorch/releases/download/1.0/efficientdet-d0.pth
# Out:
# --2023-04-07 17:07:18--  https://github.com/zylo117/Yet-Another-Efficient-Pytorch/releases/download/1.0/efficientdet-d0.pth
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/zylo117/Yet-Another-EfficientDet-Pytorch/releases/download/1.0/efficientdet-d0.pth [following]
# --2023-04-07 17:07:18--  https://github.com/zylo117/Yet-Another-EfficientDet-Pytorch/releases/download/1.0/efficientdet-d0.pth
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1yjqNeCxv0R2wOUeQeZ7Gi6LsQOIIKHah' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1yjqNeCxv0R2wOUeQeZ7Gi6LsQOIIKHah" -O youtu.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-04-07 18:16:37--  https://docs.google.com/uc?export=download&confirm=t&id=1yjqNeCxv0R2wOUeQeZ7Gi6LsQOIIKHah
# Resolving docs.google.com (docs.google.com)... 74.125.200.101, 74.125.200.100, 74.125.200.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.200.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-b8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hqts4ahje259uk7ianos66prqbgpcb9g/1680891375000/02257514593413773851/*/1yjqNeCxv0R2wOUeQeZ7Gi6LsQOIIKHah?e=download&uuid=cbe83df7-91f9-45ad-8f1a-038f89ac58ec [following]
# ...
# --2023-04-07 18:16:39--  https://doc-00-b8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hqts4ahje259uk7ianos66prqbgpcb9g/1680891375000/02257514593413773851/*/1yjqNeCxv0R2wOUeQeZ7Gi6LsQOIIKHah?e=download&uuid=cbe83df7-91f9-45ad-8f1a-038f89ac58ec
# ...

# %%
# !unzip youtu.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/12.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/13.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/14.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/15.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/16.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/17.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/18.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/19.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/2.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/20.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/21.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/22.jpg
#   inflating: client/rgb/test/9/mask/17_Mu_NT_ZTE_g_E_11_90/23.jpg
# ...

# %%
# CSV BUILDER FOR NUAA DATASET

import csv
import os

# Header for the CSV File
header = ["sno", "name", "label"]

# Path to the folder of client images
# Change the Path depending upon the location
client_directory = "../csv_dataset_builder/Detectedface/ClientFace/"
imposter_directory = "../csv_dataset_builder/Detectedface/ImposterFace/"

# Opening the CSV File
client_count = 0
imposter_count = 0
with open("./dataset_csv/nuaa_images.csv", "w", newline="") as f:
  writer = csv.writer(f)

  # Wrie the header
  writer.writerow(header)
  
  # Looping over the subdirectories in the CLIENT Folder
  for folderName in os.listdir(client_directory):
    # Looping over the images in the subdirectory and write them
    for fileName in os.listdir(os.path.join(client_directory, folderName) + "/"):
      writer.writerow([client_count, os.path.join(client_directory, folderName, fileName), 1])
      client_count += 1

  # Looping over the subdirectoris in the IMPOSTER Folder
  for folderName in os.listdir(imposter_directory):
    # Looping over the images in the subdirectory and write them
    for fileName in os.listdir(os.path.join(imposter_directory, folderName) + "/"):
      writer.writerow([client_count + imposter_count, os.path.join(imposter_directory, folderName, fileName), 0])
      imposter_count += 1

# Write the number of files
with open("./dataset_csv//nuaa_dataset_details.csv", "w", newline="") as f:
  writer = csv.writer(f)

  writer.writerow(["Client Face Images", "Imposter Face Images", "Total Images"])
  writer.writerow([client_count + 1, imposter_count, client_count + imposter_count + 1])

# %%
# import csv

# # Open the input and output files
# with open('/content/client/adaptation_list.txt', 'r') as input_file, open('output.csv', 'w', newline='') as output_file:
#     # Create a CSV writer
#     csv_writer = csv.writer(output_file)
    
#     # Write the header row
#     csv_writer.writerow(['sno', 'name', 'label'])
    
#     # Initialize the serial number
#     serial_number = 1
    
#     # Iterate over each line of the input file
#     for line in input_file:
#         # Split the line at the first space
#         first_space_index = line.find(' ')
#         file_path = line[:first_space_index]
#         label = line[first_space_index+1:].strip()
        
#         # Write the components as a row in the CSV file
#         csv_writer.writerow([serial_number, file_path, label])
        
#         # Increment the serial number
#         serial_number += 1


import csv

# Open the input and output files
with open('/content/client/test_list.txt', 'r') as input_file, open('youtu_main.csv', 'w', newline='') as output_file:
    # Create a CSV writer
    csv_writer = csv.writer(output_file)
    
    # Write the header row
    csv_writer.writerow(['sno', 'name', 'label'])
    
    # Initialize the serial number
    serial_number = 1
    
    # Iterate over each line of the input file
    for line in input_file:
        # Split the line at the second space
        first_space_index = line.find(' ')
        second_space_index = line.find(' ', first_space_index + 1)
        file_path = line[:first_space_index+1]
        label = line[second_space_index+1:].strip()
        
        # Write the components as a row in the CSV file
        csv_writer.writerow([serial_number, file_path, label])
        
        # Increment the serial number
        serial_number += 1
